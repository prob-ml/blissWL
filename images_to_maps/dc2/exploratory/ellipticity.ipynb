# %% [markdown]
# ### Average ellipticity as an estimator for shear in DC2

# %% [markdown]
# In this notebook, we assess whether the average ellipticity of neighboring galaxies is a reasonable baseline estimator for the average shear in a tile.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

# %% [markdown]
# ---

# %% [markdown]
# First, we'll do some exploratory analysis of shear and ellipticity.
#
# We unpack the `from_file` method of `LensingDC2Catalog` (which can be found in `lensing_dc2.py`) to read in a DC2 catalog and convert unlensed ellipticites to lensed ellipticities. We use the same calculation as [this notebook](https://github.com/LSSTDESC/DC2-analysis/blob/master/tutorials/matching_fof.ipynb).

# %%
catalog_full = pd.read_pickle("/data/scratch/dc2local/dc2_lensing_catalog.pkl")

# %%
# we filter to the two tracts for which we have coadded images
catalog_filtered = catalog_full[catalog_full["tract"].isin([3828, 3829])]
catalog = catalog_filtered.sample(n=50000, random_state=42)

# %%
galid = torch.from_numpy(catalog["galaxy_id"].values)
ra = torch.from_numpy(catalog["ra"].values).squeeze()
dec = torch.from_numpy(catalog["dec"].values).squeeze()

shear1 = torch.from_numpy(catalog["shear_1"].values).squeeze()
shear2 = torch.from_numpy(catalog["shear_2"].values).squeeze()
convergence = torch.from_numpy(catalog["convergence"].values)

ellip1_intrinsic = torch.from_numpy(catalog["ellipticity_1_true_dc2"].values).squeeze()
ellip2_intrinsic = torch.from_numpy(catalog["ellipticity_2_true_dc2"].values).squeeze()
ellip_intrinsic = torch.sqrt(ellip1_intrinsic**2 + ellip2_intrinsic**2)

complex_shear = shear1 + shear2 * 1j
complex_ellip = ellip1_intrinsic + ellip2_intrinsic * 1j
reduced_shear = complex_shear / (1.0 - convergence)
ellip_lensed = (complex_ellip + reduced_shear) / (1.0 + reduced_shear.conj() * complex_ellip)
ellip1_lensed = torch.view_as_real(ellip_lensed)[..., 0]
ellip2_lensed = torch.view_as_real(ellip_lensed)[..., 1]
ellip_lensed = torch.absolute(ellip_lensed)

# %% [markdown]
# We see that shear1 and shear2 are each approximately $\mathcal{N}(0, 0.015^2)$, and that they are essentially uncorrelated:

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
_ = ax[0].hist(shear1, bins=100)
_ = ax[0].set_xlabel("shear1")
_ = ax[0].set_xlim(-0.1, 0.1)
_ = ax[1].hist(shear2, bins=100)
_ = ax[1].set_xlabel("shear2")
_ = ax[1].set_xlim(-0.1, 0.1)
_ = ax[2].scatter(shear1, shear2, alpha=0.05)
_ = ax[2].set_xlabel("shear1")
_ = ax[2].set_ylabel("shear2")
_ = ax[2].set_xlim(-0.1, 0.1)
_ = ax[2].set_ylim(-0.1, 0.1)
fig.tight_layout()

# %% [markdown]
# And we find that the two components of lensed ellipticity are each symmetrically distributed around zero, and that they are uncorrelated:

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
_ = ax[0].hist(ellip1_lensed, bins=100)
_ = ax[0].set_xlabel("ellip1_lensed")
_ = ax[0].set_xlim(-1.0, 1.0)
_ = ax[1].hist(ellip2_lensed, bins=100)
_ = ax[1].set_xlabel("ellip2_lensed")
_ = ax[1].set_xlim(-1.0, 1.0)
_ = ax[2].scatter(ellip1_lensed, ellip2_lensed, alpha=0.05)
_ = ax[2].set_xlabel("ellip1_lensed")
_ = ax[2].set_ylabel("ellip2_lensed")
_ = ax[2].set_xlim(-1.0, 1.0)
_ = ax[2].set_ylim(-1.0, 1.0)
fig.tight_layout()

# %% [markdown]
# Next, we note that the effect of shear on ellipticity is very small, as the intrinsic and lensed ellipticity are very similar for both components:

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
_ = ax[0].scatter(ellip1_intrinsic, ellip1_lensed, alpha=0.01)
_ = ax[0].set_xlabel("ellip1_intrinsic")
_ = ax[0].set_ylabel("ellip1_lensed")
_ = ax[0].set_xlim(-1.0, 1.0)
_ = ax[0].set_ylim(-1.0, 1.0)
_ = ax[1].scatter(ellip2_intrinsic, ellip2_lensed, alpha=0.01)
_ = ax[1].set_xlabel("ellip2_intrinsic")
_ = ax[1].set_ylabel("ellip2_lensed")
_ = ax[1].set_xlim(-1.0, 1.0)
_ = ax[1].set_ylim(-1.0, 1.0)
fig.tight_layout()

# %% [markdown]
# And finally, we confirm that as the magnitude of shear increases, the absolute difference between the lensed and unlensed ellipticities also tends to increase:

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
_ = ax[0].scatter(shear1, (ellip1_lensed - ellip1_intrinsic).abs(), alpha=0.01)
_ = ax[0].set_xlabel("shear1")
_ = ax[0].set_ylabel("| ellip1_lensed - ellip1_intrinsic |")
_ = ax[1].scatter(shear2, (ellip2_lensed - ellip2_intrinsic).abs(), alpha=0.01)
_ = ax[1].set_xlabel("shear2")
_ = ax[1].set_ylabel("| ellip2_lensed - ellip2_intrinsic |")
fig.tight_layout()

# %% [markdown]
# ---

# %% [markdown]
# Our ground truth shear maps for DC2 are 8x8 grids of 256x256 pixel tiles, where the value of shear1 (or shear2) in each tile is the average shear1 (or shear2) of galaxies in that tile.
#
# As a baseline estimator for the average shear in each tile $T$, we compute a weighted average of the lensed ellipticities in tile $T$ and some number of adjacent tiles. To compute this weighted average, we apply a Gaussian kernel with size $s$ and standard deviation $\sigma$. We've implemented this estimator in `case_studies/weak_lensing/utils/weighted_avg_ellip.py`.
#
# Below, we tune $s$ and $\sigma$ by trying out several combinations and computing the resulting MSEs for shear1 and shear2.

# %%
import lightning as L
from hydra import compose, initialize
from hydra.utils import instantiate

from images_to_maps.dc2.dc2 import LensingDC2DataModule
from images_to_maps.utils.weighted_avg_ellip import compute_weighted_avg_ellip

device = torch.device("cuda:6" if torch.cuda.is_available() else "cpu")

# %%
ckpt = "/data/scratch/twhit/checkpoints/trained_encoder_dc2.ckpt"

with initialize(config_path="../", version_base=None):
    cfg = compose(
        "config_train_npe",
        {
            "train.pretrained_weights=" + ckpt,
        },
    )

seed = L.seed_everything(cfg.train.seed)
# Out:
# Seed set to 123123

# %%
data_source = instantiate(cfg.train.data_source)
data_source.setup("fit")
train_dl = data_source.train_dataloader()

# %%
train_data = []
for batch in train_dl:
    train_data.append(batch)

# %% [markdown]
# When the kernel size is 1, the estimator just computes the average ellipticity of galaxies in tile $T$ and does not use any of the surrounding tiles.
#
# When the kernel size is 15, the estimator uses the ellipiticities of the galaxies in all 8x8 tiles to compute its shear estimate in every tile $T$, even if tile $T$ is a corner tile.

# %%
kernel_sizes = [1, 3, 5, 7, 9, 11, 13, 15]
kernel_sigmas = [1, 3, 5, 7, 9, 11, 13, 15]

# %%
num_batches = len(train_data)

shear1 = torch.zeros(num_batches, 8 * 8 * 4)
shear2 = torch.zeros(num_batches, 8 * 8 * 4)
ellip1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas), num_batches, 8 * 8 * 4)
ellip2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas), num_batches, 8 * 8 * 4)
mse1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
corr1 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
mse2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))
corr2 = torch.zeros(len(kernel_sizes), len(kernel_sigmas))

# %%
for j in range(len(kernel_sizes)):
    for k in range(len(kernel_sigmas)):
        print(f"kernel size = {kernel_sizes[j]}, kernel sigma = {kernel_sigmas[k]}")

        for i in range(num_batches):
            tile_cat = LensingDC2DataModule.squeeze_tile_dict(train_data[i]["tile_catalog"])

            shear1[i] = tile_cat["shear_1"].flatten()
            shear2[i] = tile_cat["shear_2"].flatten()

            ellip_lsst_wavg = compute_weighted_avg_ellip(
                tile_cat, kernel_size=kernel_sizes[j], kernel_sigma=kernel_sigmas[k]
            )

            ellip1[j, k, i] = ellip_lsst_wavg[..., 0].flatten()
            ellip2[j, k, i] = ellip_lsst_wavg[..., 1].flatten()

        mse1[j, k] = ((ellip1[j, k] - shear1) ** 2).mean()
        corr1[j, k] = np.corrcoef(ellip1[j, k].flatten(), shear1.flatten())[1, 0]
        mse2[j, k] = ((ellip2[j, k] - shear2) ** 2).mean()
        corr2[j, k] = np.corrcoef(ellip2[j, k].flatten(), shear2.flatten())[1, 0]

        print(f"MSE for shear 1 = {mse1[j, k]}")
        print(f"corr coef for shear 1 = {corr1[j, k]}")
        print(f"MSE for shear 2 = {mse2[j, k]}")
        print(f"corr coef for shear 2 = {corr2[j, k]}\n")
# Out:
# kernel size = 1, kernel sigma = 1
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 3
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 5
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 7
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 9
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 11
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 13
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 1, kernel sigma = 15
# MSE for shear 1 = 0.002800985937938094
# corr coef for shear 1 = 0.0022944093216210604
# MSE for shear 2 = 0.003092959988862276
# corr coef for shear 2 = 0.0042471797205507755
#
# kernel size = 3, kernel sigma = 1
# MSE for shear 1 = 0.0005509992479346693
# corr coef for shear 1 = -0.003378227585926652
# MSE for shear 2 = 0.0005562612786889076
# corr coef for shear 2 = 0.006697544362396002
#
# kernel size = 3, kernel sigma = 3
# MSE for shear 1 = 0.0005160697037354112
# corr coef for shear 1 = -0.005141646601259708
# MSE for shear 2 = 0.0005171005614101887
# corr coef for shear 2 = 0.006176346447318792
#
# kernel size = 3, kernel sigma = 5
# MSE for shear 1 = 0.0005159508436918259
# corr coef for shear 1 = -0.00526839355006814
# MSE for shear 2 = 0.0005169491050764918
# corr coef for shear 2 = 0.00611141650006175
#
# kernel size = 3, kernel sigma = 7
# MSE for shear 1 = 0.0005159817519597709
# corr coef for shear 1 = -0.005302722100168467
# MSE for shear 2 = 0.0005169777432456613
# corr coef for shear 2 = 0.006093061063438654
#
# kernel size = 3, kernel sigma = 9
# MSE for shear 1 = 0.0005160022992640734
# corr coef for shear 1 = -0.00531677296385169
# MSE for shear 2 = 0.0005169982905499637
# corr coef for shear 2 = 0.006085450295358896
#
# kernel size = 3, kernel sigma = 11
# MSE for shear 1 = 0.0005160145228728652
# corr coef for shear 1 = -0.005323868244886398
# MSE for shear 2 = 0.0005170106305740774
# corr coef for shear 2 = 0.006081585306674242
#
# kernel size = 3, kernel sigma = 13
# MSE for shear 1 = 0.000516022031661123
# corr coef for shear 1 = -0.00532794464379549
# MSE for shear 2 = 0.0005170183721929789
# corr coef for shear 2 = 0.006079358980059624
#
# kernel size = 3, kernel sigma = 15
# MSE for shear 1 = 0.0005160269793123007
# corr coef for shear 1 = -0.005330499727278948
# MSE for shear 2 = 0.0005170233780518174
# corr coef for shear 2 = 0.006077961064875126
#
# kernel size = 5, kernel sigma = 1
# MSE for shear 1 = 0.00043737274245359004
# corr coef for shear 1 = -0.006409093271940947
# MSE for shear 2 = 0.0004285640607122332
# corr coef for shear 2 = 0.006371809169650078
#
# kernel size = 5, kernel sigma = 3
# MSE for shear 1 = 0.0003328565799165517
# corr coef for shear 1 = -0.013512641191482544
# MSE for shear 2 = 0.00030820019310340285
# corr coef for shear 2 = 0.003269337583333254
#
# kernel size = 5, kernel sigma = 5
# MSE for shear 1 = 0.00033229784457944334
# corr coef for shear 1 = -0.013830495066940784
# MSE for shear 2 = 0.00030714229797013104
# corr coef for shear 2 = 0.0027696597389876842
#
# kernel size = 5, kernel sigma = 7
# MSE for shear 1 = 0.00033244272344745696
# corr coef for shear 1 = -0.013898736797273159
# MSE for shear 2 = 0.0003071794053539634
# corr coef for shear 2 = 0.0026276186108589172
#
# kernel size = 5, kernel sigma = 9
# MSE for shear 1 = 0.00033254121080972254
# corr coef for shear 1 = -0.013924261555075645
# MSE for shear 2 = 0.00030723735108040273
# corr coef for shear 2 = 0.0025687299203127623
#
# kernel size = 5, kernel sigma = 11
# MSE for shear 1 = 0.0003325998259242624
# corr coef for shear 1 = -0.013936605304479599
# MSE for shear 2 = 0.0003072763211093843
# corr coef for shear 2 = 0.002538831438869238
#
# kernel size = 5, kernel sigma = 13
# MSE for shear 1 = 0.0003326362057123333
# corr coef for shear 1 = -0.013943526893854141
# MSE for shear 2 = 0.00030730169964954257
# corr coef for shear 2 = 0.0025216108188033104
#
# kernel size = 5, kernel sigma = 15
# MSE for shear 1 = 0.0003326599835418165
# corr coef for shear 1 = -0.013947805389761925
# MSE for shear 2 = 0.00030731866718269885
# corr coef for shear 2 = 0.0025107963010668755
#
# kernel size = 7, kernel sigma = 1
# MSE for shear 1 = 0.00042976776603609324
# corr coef for shear 1 = -0.006632318254560232
# MSE for shear 2 = 0.00041962708928622305
# corr coef for shear 2 = 0.006329198367893696
#
# kernel size = 7, kernel sigma = 3
# MSE for shear 1 = 0.00027706922264769673
# corr coef for shear 1 = -0.018015066161751747
# MSE for shear 2 = 0.00024363768170587718
# corr coef for shear 2 = -0.00014652626123279333
#
# kernel size = 7, kernel sigma = 5
# MSE for shear 1 = 0.00027403776766732335
# corr coef for shear 1 = -0.018471309915184975
# MSE for shear 2 = 0.00023976877855602652
# corr coef for shear 2 = -0.001353033003397286
#
# kernel size = 7, kernel sigma = 7
# MSE for shear 1 = 0.00027381296968087554
# corr coef for shear 1 = -0.018512099981307983
# MSE for shear 2 = 0.00023938606318552047
# corr coef for shear 2 = -0.0016722261207178235
#
# kernel size = 7, kernel sigma = 9
# MSE for shear 1 = 0.000273805926553905
# corr coef for shear 1 = -0.01851690374314785
# MSE for shear 2 = 0.0002393239556113258
# corr coef for shear 2 = -0.0018003963632509112
#
# kernel size = 7, kernel sigma = 11
# MSE for shear 1 = 0.0002738220209721476
# corr coef for shear 1 = -0.01851659268140793
# MSE for shear 2 = 0.00023931445321068168
# corr coef for shear 2 = -0.0018644564552232623
#
# kernel size = 7, kernel sigma = 13
# MSE for shear 1 = 0.00027383738779462874
# corr coef for shear 1 = -0.01851556822657585
# MSE for shear 2 = 0.0002393157919868827
# corr coef for shear 2 = -0.0019010331016033888
#
# kernel size = 7, kernel sigma = 15
# MSE for shear 1 = 0.00027384929126128554
# corr coef for shear 1 = -0.018514608964323997
# MSE for shear 2 = 0.00023931916803121567
# corr coef for shear 2 = -0.0019238790264353156
#
# kernel size = 9, kernel sigma = 1
# MSE for shear 1 = 0.0004295579274185002
# corr coef for shear 1 = -0.00664427550509572
# MSE for shear 2 = 0.0004193702479824424
# corr coef for shear 2 = 0.0063291373662650585
#
# kernel size = 9, kernel sigma = 3
# MSE for shear 1 = 0.000255109800491482
# corr coef for shear 1 = -0.022777773439884186
# MSE for shear 2 = 0.0002173160610254854
# corr coef for shear 2 = -0.0011434548068791628
#
# kernel size = 9, kernel sigma = 5
# MSE for shear 1 = 0.0002494779182597995
# corr coef for shear 1 = -0.02435467578470707
# MSE for shear 2 = 0.00021017319522798061
# corr coef for shear 2 = -0.0031602485105395317
#
# kernel size = 9, kernel sigma = 7
# MSE for shear 1 = 0.00024892075452953577
# corr coef for shear 1 = -0.02459726855158806
# MSE for shear 2 = 0.00020933421910740435
# corr coef for shear 2 = -0.003766284789890051
#
# kernel size = 9, kernel sigma = 9
# MSE for shear 1 = 0.00024884476442821324
# corr coef for shear 1 = -0.024664564058184624
# MSE for shear 2 = 0.00020916337962262332
# corr coef for shear 2 = -0.0040196506306529045
#
# kernel size = 9, kernel sigma = 11
# MSE for shear 1 = 0.00024884287267923355
# corr coef for shear 1 = -0.024690818041563034
# MSE for shear 2 = 0.00020911847241222858
# corr coef for shear 2 = -0.004148536827415228
#
# kernel size = 9, kernel sigma = 13
# MSE for shear 1 = 0.00024885323364287615
# corr coef for shear 1 = -0.024703456088900566
# MSE for shear 2 = 0.00020910566672682762
# corr coef for shear 2 = -0.004222817253321409
#
# kernel size = 9, kernel sigma = 15
# MSE for shear 1 = 0.0002488641475792974
# corr coef for shear 1 = -0.024710457772016525
# MSE for shear 2 = 0.00020910261082462966
# corr coef for shear 2 = -0.00426947046071291
#
# kernel size = 11, kernel sigma = 1
# MSE for shear 1 = 0.0004295557155273855
# corr coef for shear 1 = -0.006644354667514563
# MSE for shear 2 = 0.0004193676286377013
# corr coef for shear 2 = 0.0063290828838944435
#
# kernel size = 11, kernel sigma = 3
# MSE for shear 1 = 0.0002455132198520005
# corr coef for shear 1 = -0.022763729095458984
# MSE for shear 2 = 0.00020618434064090252
# corr coef for shear 2 = -0.0019771060906350613
#
# kernel size = 11, kernel sigma = 5
# MSE for shear 1 = 0.00023695497657172382
# corr coef for shear 1 = -0.023295532912015915
# MSE for shear 2 = 0.000196128137758933
# corr coef for shear 2 = -0.005115068983286619
#
# kernel size = 11, kernel sigma = 7
# MSE for shear 1 = 0.00023587483156006783
# corr coef for shear 1 = -0.02295847423374653
# MSE for shear 2 = 0.0001948963908944279
# corr coef for shear 2 = -0.006148322019726038
#
# kernel size = 11, kernel sigma = 9
# MSE for shear 1 = 0.0002356498735025525
# corr coef for shear 1 = -0.022737672552466393
# MSE for shear 2 = 0.00019465260265860707
# corr coef for shear 2 = -0.006585695780813694
#
# kernel size = 11, kernel sigma = 11
# MSE for shear 1 = 0.00023559019609820098
# corr coef for shear 1 = -0.02260632812976837
# MSE for shear 2 = 0.00019459400209598243
# corr coef for shear 2 = -0.006808542180806398
#
# kernel size = 11, kernel sigma = 13
# MSE for shear 1 = 0.00023557319946121424
# corr coef for shear 1 = -0.02252465859055519
# MSE for shear 2 = 0.00019458096357993782
# corr coef for shear 2 = -0.006936944089829922
#
# kernel size = 11, kernel sigma = 15
# MSE for shear 1 = 0.000235569168580696
# corr coef for shear 1 = -0.0224711112678051
# MSE for shear 2 = 0.0001945807016454637
# corr coef for shear 2 = -0.007017546333372593
#
# kernel size = 13, kernel sigma = 1
# MSE for shear 1 = 0.0004295557155273855
# corr coef for shear 1 = -0.006644354667514563
# MSE for shear 2 = 0.0004193676286377013
# corr coef for shear 2 = 0.006329082418233156
#
# kernel size = 13, kernel sigma = 3
# MSE for shear 1 = 0.0002414505579508841
# corr coef for shear 1 = -0.022250650450587273
# MSE for shear 2 = 0.0002016765356529504
# corr coef for shear 2 = -0.0019554700702428818
#
# kernel size = 13, kernel sigma = 5
# MSE for shear 1 = 0.00023015296028461307
# corr coef for shear 1 = -0.02117900922894478
# MSE for shear 2 = 0.00018939394794870168
# corr coef for shear 2 = -0.005454944912344217
#
# kernel size = 13, kernel sigma = 7
# MSE for shear 1 = 0.00022843443730380386
# corr coef for shear 1 = -0.020002039149403572
# MSE for shear 2 = 0.0001878313923953101
# corr coef for shear 2 = -0.006681504659354687
#
# kernel size = 13, kernel sigma = 9
# MSE for shear 1 = 0.00022800045553594828
# corr coef for shear 1 = -0.01937221549451351
# MSE for shear 2 = 0.00018752957112155855
# corr coef for shear 2 = -0.007204881869256496
#
# kernel size = 13, kernel sigma = 11
# MSE for shear 1 = 0.0002278510364703834
# corr coef for shear 1 = -0.019019566476345062
# MSE for shear 2 = 0.00018746330169960856
# corr coef for shear 2 = -0.0074715809896588326
#
# kernel size = 13, kernel sigma = 13
# MSE for shear 1 = 0.00022778795391786844
# corr coef for shear 1 = -0.01880633272230625
# MSE for shear 2 = 0.00018745312991086394
# corr coef for shear 2 = -0.007625111378729343
#
# kernel size = 13, kernel sigma = 15
# MSE for shear 1 = 0.00022775722027290612
# corr coef for shear 1 = -0.018668655306100845
# MSE for shear 2 = 0.00018745753914117813
# corr coef for shear 2 = -0.007721399888396263
#
# kernel size = 15, kernel sigma = 1
# MSE for shear 1 = 0.0004295557155273855
# corr coef for shear 1 = -0.006644354667514563
# MSE for shear 2 = 0.0004193676286377013
# corr coef for shear 2 = 0.006329082418233156
#
# kernel size = 15, kernel sigma = 3
# MSE for shear 1 = 0.00024045712780207396
# corr coef for shear 1 = -0.022138439118862152
# MSE for shear 2 = 0.00020050436432939023
# corr coef for shear 2 = -0.0018564405618235469
#
# kernel size = 15, kernel sigma = 5
# MSE for shear 1 = 0.00022796695702709258
# corr coef for shear 1 = -0.02020493894815445
# MSE for shear 2 = 0.0001870277337729931
# corr coef for shear 2 = -0.004852052312344313
#
# kernel size = 15, kernel sigma = 7
# MSE for shear 1 = 0.00022598291980102658
# corr coef for shear 1 = -0.018459632992744446
# MSE for shear 2 = 0.00018522187019698322
# corr coef for shear 2 = -0.005751169752329588
#
# kernel size = 15, kernel sigma = 9
# MSE for shear 1 = 0.00022548303240910172
# corr coef for shear 1 = -0.017535969614982605
# MSE for shear 2 = 0.00018486428598407656
# corr coef for shear 2 = -0.006102601997554302
#
# kernel size = 15, kernel sigma = 11
# MSE for shear 1 = 0.00022531389549840242
# corr coef for shear 1 = -0.017020683735609055
# MSE for shear 2 = 0.00018478337733540684
# corr coef for shear 2 = -0.0062730927020311356
#
# kernel size = 15, kernel sigma = 13
# MSE for shear 1 = 0.00022524423548020422
# corr coef for shear 1 = -0.016709689050912857
# MSE for shear 2 = 0.00018476959667168558
# corr coef for shear 2 = -0.006368398666381836
#
# kernel size = 15, kernel sigma = 15
# MSE for shear 1 = 0.00022521134815178812
# corr coef for shear 1 = -0.01650911197066307
# MSE for shear 2 = 0.00018477364210411906
# corr coef for shear 2 = -0.0064270636066794395

# %% [markdown]
# We plot the MSE for each kernel size and standard deviation. For both shear1 and shear2, we find that a larger kernel size is better and that the kernel standard deviation does not matter too much as long as it is at least 2.

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))

_ = ax[0].plot(mse1)
_ = ax[0].set_ylim((1e-4, 5e-4))
_ = ax[0].legend(kernel_sigmas, title="kernel sd")
_ = ax[0].set_xticks(ticks=torch.arange(8), labels=kernel_sizes)
_ = ax[0].set_xlabel("kernel size")
_ = ax[0].set_ylabel("MSE for shear 1")
_ = ax[0].set_yscale("log")

_ = ax[1].plot(mse2)
_ = ax[1].set_ylim((5e-5, 1e-3))
_ = ax[1].legend(kernel_sigmas, title="kernel sd")
_ = ax[1].set_xticks(ticks=torch.arange(8), labels=kernel_sizes)
_ = ax[1].set_xlabel("kernel size")
_ = ax[1].set_ylabel("MSE for shear 2")
_ = ax[1].set_yscale("log")

fig.tight_layout()

# %% [markdown]
# Based on this metric, we conclude that larger kernel sizes and kernel standard deviations are better. We set both to 15.
